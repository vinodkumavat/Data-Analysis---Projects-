# %% [markdown]
# ## Netflix Data Set
#
# ### Dataset contains data till 2021.

# %%
import pandas as pd
data = pd.read_csv('Netflix_Data.csv')
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# .
# ## Basic information about dataset
#
# ### 1) head()

# %%
data.head(6)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# ...

# %% [markdown]
# ### 2) tail()

# %%
data.tail(3)
# Out:
#      Show_Id Category                                    Title  Director  \
# 7786   s7785    Movie                        Zulu Man in Japan       NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts       NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  Sam Dunn
#
#                             Cast                                Country  \
# 7786                     Nasty C                                    NaN
# 7787  Adriano Zumbo, Rachel Khoo                              Australia
# 7788                         NaN  United Kingdom, Canada, United States
#
#             Release_Date Rating  Duration  \
# 7786  September 25, 2020  TV-MA    44 min
# 7787    October 31, 2020  TV-PG  1 Season
# 7788       March 1, 2020  TV-MA    90 min
#
#                                                    Type  \
# 7786  Documentaries, International Movies, Music & M...
# 7787                 International TV Shows, Reality TV
# ...

# %% [markdown]
# ### 3) shape

# %%
# (row, columns)
data.shape
# Out:
# (7789, 11)

# %% [markdown]
# ### 4) size

# %%
# number of data present
# row x columns = size
data.size
# Out:
# 85679

# %% [markdown]
# ### 5) columns

# %%
# get the column names
data.columns[:]
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# ### 6) dtypes

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# ### 7) info()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# .
# ## Now do Tasks

# %% [markdown]
# .
# ### 1) Is there any duplicate record in this dataset ?
# ### If yes, then remove the duplicate records.

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
data.shape
# Out:
# (7789, 11)

# %%
# give boolean result
data.duplicated()

# give data frame that is dublicate
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
# Removing dubplicate records and give the copy
data.drop_duplicates()

# for making the record free from duplicate
data.drop_duplicates(inplace = True)

# show data shape to varify
data.shape
# Out:
# (7787, 11)

# %% [markdown]
# .
# ### 2) Is there any Null present in any column ?
# ### show with heat-map --- (Seaborn library)

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
# will give boolean result
data.isnull()

# geting count of null value
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
# Plotting the heat map
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# .
# ## Questions Answer type analysis

# %% [markdown]
# .
# ### 1) For 'House of Cards', what is the show id and who is the director of this show?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
# Method - 1 using isin()

# column used is Title
# select the column and use isin() will give boolean result
data['Title'].isin(['House of Cards'])

# taking dataframe
data[data['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
# Method - 2 using str.contains()

# select the column and use isin() will give boolean result
data['Title'].str.contains('House of Cards')

# taking dataframe
data[data['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# .
# ### 2) In which year highest number of the TV shows & movies released ? Show with bar graph.

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
# converting the 'Release_Date' to datatime formate and assigning it back to same column
data['Release_Date'] = pd.to_datetime(data['Release_Date'])

# printing the data type
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date    datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# dtype: object

# %%
# getting the year
data['Release_Date'].dt.year

# now couting the different values i.e. using value count function
data['Release_Date'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Release_Date, dtype: int64

# %%
# Now bar graph
# getting above values
data['Release_Date'].dt.year.value_counts()

# pplotting the bar graph
data['Release_Date'].dt.year.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# .
# ### 3) How many movies & TV shows are in the dataset ? Show the bar graph.

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
# will use the value count function for column 'Category'
data['Category'].value_counts()
# Out:
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
# Method - 1 for plotting the bar graph
data['Category'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
# Method - 2 for plotting the bar graph using seaborn library
sns.countplot(data['Category'])
# Out:
# E:\Programming\Applications\College\Installation-Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# .
# ### 4) Show all the movies that were released in year 2020.

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
# since datatype of Release Date column is already changed to datetime formate
# so no need to change again

# selecting the year
data['Release_Date'].dt.year

# comparing with 2020 will give boolean result
data['Release_Date'].dt.year == 2020

# getting the dataframe
data[data['Release_Date'].dt.year == 2020]
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 24       s25  TV Show      ​SAINT SEIYA: Knights of the Zodiac
# ...      ...      ...                                      ...
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#              Director                                               Cast  \
# 0                 NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# .
# ### 5) Show only the title of all TV shows that were released in India only.

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
# selecting the country as India, getting boolean result
data['Country'] == 'India'

# selecting the Category as TV shows, getting boolean result
data['Category'] == 'TV Show'

# Now both condition must meet so using and operator, getting boolean result
(data['Country'] == 'India') & (data['Category'] == 'TV Show')

# now getting dataframe
data[(data['Country'] == 'India') & (data['Category'] == 'TV Show')]

# need only the title column
data[(data['Country'] == 'India') & (data['Category'] == 'TV Show')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# .
# ### 6) Show top 10 Directors, who gave the highest number of TV shows & Movies to Netflix.

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
# we can use groupby function or value_counts() function
data['Director'].value_counts()

# need only top 10
data['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %% [markdown]
# .
# ### 7) Show all the Records, where 'Category' = Movie and 'Type' = Comedies' or Country is 'United Kingdom'

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
# selecting the Category = Movie, getting boolean result
data['Category'] == 'Movie'

# selecting the Types = Comedies, getting boolean result
data['Type'] == 'Comedies'

# selecting the country = United Kingdom, getting boolean result
data['Country'] == 'United Kingdom'

# Now taking or for type and country, getting boolean result
(data['Type'] == 'Comedies') | (data['Country'] == 'United Kingdom')

# now getting the and with Category with above one, getting boolean result
(data['Category'] == 'Movie') & ((data['Type'] == 'Comedies') | (data['Country'] == 'United Kingdom'))

# now getting dataframe
data[(data['Category'] == 'Movie') & ((data['Type'] == 'Comedies') | (data['Country'] == 'United Kingdom'))]
# Out:
#      Show_Id Category                   Title                Director  \
# 19       s20    Movie                     '89                     NaN
# 33       s34    Movie            #realityhigh        Fernando Lebrija
# 72       s73    Movie                17 Again             Burr Steers
# 82       s83    Movie     2036 Origin Unknown           Hasraf Dulull
# 84       s85    Movie               21 & Over  Jon Lucas, Scott Moore
# ...      ...      ...                     ...                     ...
# 7634   s7633    Movie            Wine Country             Amy Poehler
# 7649   s7648    Movie           Without Gorky          Cosima Spender
# 7664   s7663    Movie                 Work It           Laura Terruso
# 7688   s7687    Movie  XV: Beyond the Tryline        Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu             James Brown
#
#                                                    Cast         Country  \
# ...

# %% [markdown]
# .
# ### 8) In how many movies/shows, Tom Cruise was cast ?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
# we need ot check if Tom Cruise is present in 'Cast' column or not
# will use str.contains('Tom Cruise')

# pick up the column
data['Cast']

# using string function to check Tom, will give result in boolean form
data['Cast'].str.contains('Tom Cruise')

# getting the datafram
data[data['Cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [119], in <cell line: 11>()
#       8 data['Cast'].str.contains('Tom Cruise')
#      10 # getting the datafram
# ---> 11 data[data['Cast'].str.contains('Tom Cruise')]
#
# File E:\Programming\Applications\College\Installation-Anaconda\lib\site-packages\pandas\core\frame.py:3495, in DataFrame.__getitem__(self, key)
#    3492     return self.where(key)
#    3494 # Do we have a (boolean) 1d indexer?
# -> 3495 if com.is_bool_indexer(key):
#    3496     return self._getitem_bool_array(key)
#    3498 # We are left with two options: a single key, and a collection of keys,
#    3499 # We interpret tuples as collections only for non-MultiIndex
#
# File E:\Programming\Applications\College\Installation-Anaconda\lib\site-packages\pandas\core\common.py:144, in is_bool_indexer(key)
# ...

# %%
# since we have null values present in the data so we need to remove that

df_2 = data.dropna()
df_2
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
# now the new data frame is free from null values so we can use
df_2[df_2['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description
# 3860  Through chance, human action, past history and...
# 5071  A fast-talking yuppie is forced to slow down w...

# %% [markdown]
# .
# ### 9) What are the different Ratings defined by Netflix ?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
# we need the unique value of 'Rating' columns

# selecting column
data['Rating']

# getting the unique values only
data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
# to get the count of unique value
# excluding the null value
data['Rating'].nunique()
# Out:
# 14

# %% [markdown]
# .
# ### 10) How many movies got the 'TV-14' rating in Canada ?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
# selecting the country = Canada
data['Country'] == 'Canada'

# selecting the rating = TV-14
data['Rating'] == 'TV-14'

# selecting Category = Movie
data['Category'] == 'Movie'

# taking all condition so use and operator, will give boolean result
(data['Country'] == 'Canada') & (data['Rating'] == 'TV-14') & (data['Category'] == 'Movie')

# getting dataframe
data[(data['Country'] == 'Canada') & (data['Rating'] == 'TV-14') & (data['Category'] == 'Movie')]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %%
# to get the count (row = count we needed, column)
data[(data['Country'] == 'Canada') & (data['Rating'] == 'TV-14') & (data['Category'] == 'Movie')].shape
# Out:
# (11, 11)

# %% [markdown]
# .
# ### 11) How many TV show got the 'R' rating, after year 2018?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date    datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# dtype: object

# %%
# selecting the year
data['Release_Date'].dt.year

#  year > 2018
data['Release_Date'].dt.year > 2018

# selecting the rating = R
data['Rating'] == 'R'

# selecting Category = TV Show
data['Category'] == 'TV Show'

# taking all conditions, boolean result
(data['Release_Date'].dt.year > 2018) & (data['Rating'] == 'R') & (data['Category'] == 'TV Show')

# getting data frame
data[(data['Release_Date'].dt.year > 2018) & (data['Rating'] == 'R') & (data['Category'] == 'TV Show')]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN   2019-04-25
#
#      Rating  Duration      Type  \
# 6437      R  1 Season  TV Shows
#
#                                             Description
# 6437  Trapped at a stagecoach stop as a storm rages ...

# %% [markdown]
# .
# ### 12) What is the maximum duration of a Movie/TV show on Netflix ?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
# checking the uniques values in Duration column
data['Duration'].unique
# Out:
# <bound method Series.unique of 0       4 Seasons
# 1          93 min
# 2          78 min
# 3          80 min
# 4         123 min
#           ...
# 7784       99 min
# 7785      111 min
# 7786       44 min
# 7787     1 Season
# 7788       90 min
# Name: Duration, Length: 7787, dtype: object>

# %%
# checking the dtypes of that column
data['Duration'].dtypes
# Out:
# dtype('O')

# %%
# use split string method to split the value and min dimension
data['Duration'].str.split(' ', expand = True)
# Out:
#         0        1
# 0       4  Seasons
# 1      93      min
# 2      78      min
# 3      80      min
# 4     123      min
# ...   ...      ...
# 7784   99      min
# 7785  111      min
# 7786   44      min
# 7787    1   Season
# 7788   90      min
#
# [7787 rows x 2 columns]

# %%
# assigning to dataframe
data[['Minutes', 'Units']] = data['Duration'].str.split(' ', expand = True)

# showing dataframe
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description Minutes    Units
# 0  In a future where the elite inhabit an island ...       4  Seasons
# 1  After a devastating earthquake hits Mexico Cit...      93      min

# %%
# now maximum for 'Minutes' Col is the answer
data['Minutes'].max()
# Out:
# '99'

# %% [markdown]
# .
# ### 13) Which individual country has the Highest No. of TV shows ?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description Minutes    Units
# 0  In a future where the elite inhabit an island ...       4  Seasons
# 1  After a devastating earthquake hits Mexico Cit...      93      min

# %%
# selecting Category = TV Show
data['Category'] == 'TV Show'

# getting dataframe
data[data['Category'] == 'TV Show']

# now selecting the Country column
data[data['Category'] == 'TV Show']['Country']

# Now using value_counts function to get the count for each uniques country
data[data['Category'] == 'TV Show']['Country'].value_counts()
# Out:
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: Country, Length: 183, dtype: int64

# %% [markdown]
# .
# ### 14) How can we sort the dataset by Year ?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description Minutes    Units
# 0  In a future where the elite inhabit an island ...       4  Seasons
# 1  After a devastating earthquake hits Mexico Cit...      93      min

# %%
# selecting the year from release col
data['Year'] = data['Release_Date'].dt.year

data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description Minutes    Units    Year
# 0  In a future where the elite inhabit an island ...       4  Seasons  2020.0
# 1  After a devastating earthquake hits Mexico Cit...      93      min  2016.0

# %%
# using sort function
data.sort_values(by = 'Year', ascending = False)

# getting the top 3
data.sort_values(by = 'Year', ascending = False).head(3)
# Out:
#      Show_Id Category            Title                 Director  \
# 5564   s5564    Movie  Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie        Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show     Bling Empire                      NaN
#
#                                                    Cast  \
# 5564  Robert Downey Jr., Jude Law, Rachel McAdams, M...
# 5919  Shia LaBeouf, Jeff Bridges, Zooey Deschanel, J...
# 980                                                 NaN
#
#                                                 Country Release_Date Rating  \
# 5564  United States, Germany, United Kingdom, Australia   2021-01-01  PG-13
# 5919                                      United States   2021-01-01     PG
# 980                                                 NaN   2021-01-15  TV-MA
#
#       Duration                                               Type  \
# 5564   128 min                       Action & Adventure, Comedies
# ...

# %% [markdown]
# .
# ### 15) Find all the instances where:
#
# #### Category = Movie and Type = 'Dramas'
# #### or
# #### Category = 'TV Show' and Type = 'Kids' TV'

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description Minutes    Units    Year
# 0  In a future where the elite inhabit an island ...       4  Seasons  2020.0
# 1  After a devastating earthquake hits Mexico Cit...      93      min  2016.0

# %%
# selecting category = Movie
data['Category'] == 'Movie'

# selecting Type = Dramas
data['Type'] == 'Dramas'

# Taking and of both conditions
(data['Category'] == 'Movie') & (data['Type'] == 'Dramas')


# selecting category = TV Show
data['Category'] == 'TV Show'

# selecting Type = Dramas
data['Type'] == "Kids' TV"

# taking add of above two
(data['Category'] == 'TV Show') & (data['Type'] == "Kids' TV")


# finally taking OR
((data['Category'] == 'Movie') & (data['Type'] == 'Dramas')) | ((data['Category'] == 'TV Show') & (data['Type'] == "Kids' TV"))

# getting the dataframe
data[((data['Category'] == 'Movie') & (data['Type'] == 'Dramas')) | ((data['Category'] == 'TV Show') & (data['Type'] == "Kids' TV"))
]
# Out:
#      Show_Id Category                       Title        Director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7668   s7667  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  TV Show                        Yoko             NaN
# 7719   s7718  TV Show                         YOM             NaN
# 7758   s7757  TV Show                          Z4             NaN
# 7761   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...
